# %% [markdown]
# ## $$\text{Bosques Aleatorios}$$
# $$\text{Inspirado de la sabiduria de masas}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('../data/Position_Salaries.csv')
x = df.iloc[:,1].values.reshape(-1,1)
y = df.iloc[:,2].values.reshape(-1,1)

# %% [markdown]
# ### Ajustamos el modelo

# %%
from sklearn.ensemble import RandomForestRegressor 

reg = RandomForestRegressor(n_estimators=10, random_state=0)
reg = reg.fit(x,y.ravel())

# %% [markdown]
# ### Predecimos

# %%
# Un talento menciona que gana 160 000 por los seis años y medio
y_pred = reg.predict([[6.5]])
y_pred
# Out:
# array([167000.])

# %% [markdown]
# ### Visualizamos

# %%
x_grid = np.arange(min(x),max(x),0.01)
x_grid = x_grid.reshape(-1,1)
plt.scatter(x,y)
plt.plot(x_grid,reg.predict(x_grid),color="red")
plt.show()

# %% [markdown]
# Podemos ver que los árboles y bosques son discretos
